# %% [markdown]
# # File Handling

# %%
# File handling

file = open("reports.txt", "r")
print(file.read())
# Out:
# Hello world
# file handling

# %%
file = open("reports1.txt", "w")
file.write('Not a good day today')
file.close()

# %%
with open("reports.txt", "r") as file:
    content = file.read()

# File is closed here automatically, even if an error occurred
print(content)
# Out:
# Hello world
# file handling

# %%
with open("reports.txt", "r") as file:
    content = file.readlines()

print(content)

for line in content:
    
    print(line.strip('\n'))
# Out:
# ['Hello world\n', 'file handling\n']
# Hello world
# file handling

# %%
with open("summary.txt", "w") as f:
    f.write("Pipeline run: complete\n")
    f.write("Records processed: 9500\n")
    f.write("Errors: 0\n")

# %%
with open("summary.txt", "r") as f:
    print(f.read())
# Out:
# Pipeline run: complete
# Records processed: 9500
# Errors: 0
# Next run scheduled: 02:00 UTC
# Next run scheduled: 02:00 UTC

# %%
with open("summary.txt", "a") as f:
    f.write("Next run scheduled: 02:00 UTC\n")

# %%
lines = [
    "Region: Asia Pacific\n",
    "Status: Active\n",
    "Clients: 14\n"
]

with open("region.txt", "w") as f:
    f.writelines(lines)

# %%
with open("region.txt" , "a") as f:
    f.write('None : Checked')

# %%
# openpyxl

# %%
pip install csv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for csv

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\vardan kumar\appdata\local\programs\python\python314\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\vardan kumar\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vardan kumar\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\vardan kumar\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\vardan kumar\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import csv

# %%
with open("employees.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row["name"], "—", row["department"])
# Out:
# Alice — Engineering
# Bob — Finance
# Carol — Engineering

# %%
import csv

records = [
    {"id": 1, "name": "Alice", "department": "Engineering", "status": "active"},
    {"id": 2, "name": "Bob",   "department": "Finance",     "status": "active"},
]

with open("output.csv", "w", newline="") as f:
    fieldnames = ["id", "name", "department", "status"]
    writer = csv.DictWriter(f, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(records)

# %%
with open("output.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row["name"], "-", row["department"])
# Out:
# Alice - Engineering
# Bob - Finance

# %%
import json

response = '{"status": "ok", "records": 4200, "errors": null}'
data = json.loads(response)

print(type(data))
print(data["status"])
print(data["records"])
print(data["errors"])
# Out:
# <class 'dict'>
# ok
# 4200
# None

# %%
result = {
    "pipeline": "daily_load",
    "rows_loaded": 9500,
    "success": True
}

json_string = json.dumps(result)
print(json_string)
print(type(json_string))
# Out:
# {"pipeline": "daily_load", "rows_loaded": 9500, "success": true}
# <class 'str'>

# %%
print(json.dumps(result, indent=4))
# Out:
# {
#     "pipeline": "daily_load",
#     "rows_loaded": 9500,
#     "success": true
# }
